# %% [markdown]
# ## Scipy:
#
# We have the min and max temperatures in a city In India for each months of the year.
#
# We would like to find a function to describe this and show it graphically, the dataset given below.
#
# Task:
# 1. fitting it to the periodic function
#
# 2. plot the fit
#
# Data
#
# Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
#
# Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18
#
# Expected Output:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
max_temp  = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
min_temp  = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])
months = np.arange(1,13)
# Out:
# 25.0

# %%
plt.figure(figsize=[10,6])
plt.plot(months,max_temp,'ro')
plt.plot(months,min_temp,'bo')
plt.xlabel('Month')
plt.ylabel('Temperature')
plt.title("Min/max Temperature")
# Out:
# Text(0.5, 1.0, 'Min/max Temperature')

# %%
from scipy import optimize
from scipy import special
from scipy import sqrt

# I searched a lot, how to derive at this funcion, tried using given in help,which does not fit the curve well

def yearly_temps(times, avg, ampl, time_offset):
    return (avg + ampl * np.cos((times + time_offset) * 2 * np.pi / times.max()))
    

res_max, cov_max = optimize.curve_fit(yearly_temps, months,max_temp, [40,20,0])

res_min, cov_min = optimize.curve_fit(yearly_temps, months,min_temp, [-40,20,0])

print(res_max)
print(res_min)
days = np.linspace(0, 12, num=365)

plt.figure(figsize=[8,6])

plt.plot(months, max_temp, 'ro')
plt.plot(days, yearly_temps(days, *res_max), 'r-')

plt.plot(months, min_temp, 'bo')
plt.plot(days, yearly_temps(days, *res_min), 'b-')

plt.xlabel('Month')
plt.ylabel('Temperature ')

plt.show()
# Out:
# [ 39.25       -11.01878017   0.97111097]
# [25.         -7.86539576  0.4895256 ]

# %% [markdown]
# ## Matplotlib:
#
# This assignment is for visualization using matplotlib:
# data to use:
# url=https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv
# titanic = pd.read_csv(url)
# Charts to plot:
# 1. Create a pie chart presenting the male/female proportion

# %%
url="https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv"
titanic = pd.read_csv(url)
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
t = titanic.iloc[0]

# %%
titanic.head(3)
# Out:
#    pclass  survived                            name     sex      age  sibsp  \
# 0     1.0       1.0   Allen, Miss. Elisabeth Walton  female  29.0000    0.0
# 1     1.0       1.0  Allison, Master. Hudson Trevor    male   0.9167    1.0
# 2     1.0       0.0    Allison, Miss. Helen Loraine  female   2.0000    1.0
#
#    parch  ticket      fare    cabin embarked boat  body  \
# 0    0.0   24160  211.3375       B5        S    2   NaN
# 1    2.0  113781  151.5500  C22 C26        S   11   NaN
# 2    2.0  113781  151.5500  C22 C26        S  NaN   NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON

# %%
parts = titanic['sex'].value_counts()
fig1, ax1 = plt.subplots()
ax1.pie(parts,  labels=['male','female'], autopct='%1.1f%%',shadow=True, startangle=90,colors = ['blue','pink'])
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
cols = { 'female': 0,'male' : 1}
plt.scatter(x='age',y ='fare',c = titanic.sex.map(cols) ,data=titanic)

# %%
#Using seaborn

import seaborn as sns
sns.scatterplot(x='age',y ='fare',hue = 'sex' ,data=titanic)
